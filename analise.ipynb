# %% [markdown]
# # Importar as funções dos Packages

# %%
from Package import pesquisa as p
from Package import analise as a
import random

# %% [markdown]
# # Estudo dos diferentes casos para as pesquisas
#
# 1. Melhor caso - Primeiro elemento da lista
# 2. Pior caso - Elemento que não se encontra na lista
# 3. Caso intermédio - Um elemento aleatório da lista
#
# Nos exemplos usei as lista com 100 elementos pois é mais rápido a analisar

# %% [markdown]
# ## Listas Ordenadas

# %% [markdown]
# ### Estudo do melhor caso, pior caso e do caso intermédio na função da pesquisa sequencial

# %%
quantidades = [100]
valor_max = 1000000

tempos_pesquisa_sequencial_ordenado = {"melhor_caso": [], "pior_caso": [], "caso_intermedio": []}

for quantidade in quantidades:
    ficheiro_ordenado = f'ordenado_{quantidade}.txt'
    with open(ficheiro_ordenado, 'r') as ficheiro:
        linhas = ficheiro.readlines()
        inteiros = [int(numero) for linha in linhas for numero in linha.strip().replace('[', '').replace(']', '').split(',')]

    item_melhor_caso = inteiros[0]

    item_pior_caso = -1

    item_caso_intermedio = inteiros[random.randint(0, len(inteiros) - 1)]

    print(f'Pesquisa Sequencial para {quantidade} ordenado (Melhor Caso):')
    dic_stats, dic_tempos = a.complexidade(p.pesquisa_sequencial, ficheiro_ordenado, [item_melhor_caso], 500)
    tempos_pesquisa_sequencial_ordenado["melhor_caso"].extend(dic_tempos[item_melhor_caso])
    print(dic_stats)

    print(f'Pesquisa Sequencial para {quantidade} ordenado (Pior Caso):')
    dic_stats, dic_tempos = a.complexidade(p.pesquisa_sequencial, ficheiro_ordenado, [item_pior_caso], 500)
    tempos_pesquisa_sequencial_ordenado["pior_caso"].extend(dic_tempos[item_pior_caso])
    print(dic_stats)

    print(f'Pesquisa Sequencial para {quantidade} ordenado (Caso Intermediário):')
    dic_stats, dic_tempos = a.complexidade(p.pesquisa_sequencial, ficheiro_ordenado, [item_caso_intermedio], 500)
    tempos_pesquisa_sequencial_ordenado["caso_intermedio"].extend(dic_tempos[item_caso_intermedio])
    print(dic_stats)
# Out:
# Pesquisa Sequencial para 100 ordenado (Melhor Caso):
# {8926: (0.0, 0.0)}
# Pesquisa Sequencial para 100 ordenado (Pior Caso):
# {-1: (0.0, 0.0)}
# Pesquisa Sequencial para 100 ordenado (Caso Intermediário):
# {677152: (0.0, 0.0)}

# %%
a.complexidade_boxplot(tempos_pesquisa_sequencial_ordenado)

# %% [markdown]
# ### Estudo do melhor caso, pior caso e do caso intermédio na função da pesquisa sequencial recursiva

# %%
quantidades = [100]
valor_max = 1000000

tempos_pesquisa_sequencial_recursiva_ordenado = {"melhor_caso": [], "pior_caso": [], "caso_intermedio": []}

for quantidade in quantidades:
    ficheiro_ordenado = f'ordenado_{quantidade}.txt'
    with open(ficheiro_ordenado, 'r') as ficheiro:
        linhas = ficheiro.readlines()
        inteiros = [int(numero) for linha in linhas for numero in linha.strip().replace('[', '').replace(']', '').split(',')]

    item_melhor_caso = inteiros[0]

    item_pior_caso = -1

    item_caso_intermedio = inteiros[random.randint(0, len(inteiros) - 1)]

    print(f'Pesquisa Sequencial Recursiva para {quantidade} ordenado (Melhor Caso):')
    dic_stats, dic_tempos = a.complexidade(p.pesquisa_sequencial_recursiva, ficheiro_ordenado, [item_melhor_caso], 500)
    tempos_pesquisa_sequencial_recursiva_ordenado["melhor_caso"].extend(dic_tempos[item_melhor_caso])
    print(dic_stats)

    print(f'Pesquisa Sequencial Recursiva para {quantidade} ordenado (Pior Caso):')
    dic_stats, dic_tempos = a.complexidade(p.pesquisa_sequencial_recursiva, ficheiro_ordenado, [item_pior_caso], 500)
    tempos_pesquisa_sequencial_recursiva_ordenado["pior_caso"].extend(dic_tempos[item_pior_caso])
    print(dic_stats)

    print(f'Pesquisa Sequencial Recursiva para {quantidade} ordenado (Caso Intermediário):')
    dic_stats, dic_tempos = a.complexidade(p.pesquisa_sequencial_recursiva, ficheiro_ordenado, [item_caso_intermedio], 500)
    tempos_pesquisa_sequencial_recursiva_ordenado["caso_intermedio"].extend(dic_tempos[item_caso_intermedio])
    print(dic_stats)
# Out:
# Pesquisa Sequencial Recursiva para 100 ordenado (Melhor Caso):
# {8926: (2.8133392333984377e-06, 6.290817769646053e-05)}
# Pesquisa Sequencial Recursiva para 100 ordenado (Pior Caso):
# {-1: (2.013683319091797e-06, 4.502732786646658e-05)}
# Pesquisa Sequencial Recursiva para 100 ordenado (Caso Intermediário):
# {200639: (2.0003318786621095e-06, 4.472878058248338e-05)}

# %%
a.complexidade_boxplot(tempos_pesquisa_sequencial_recursiva_ordenado)

# %% [markdown]
# ### Estudo do melhor caso, pior caso e do caso intermédio na função da pesquisa binária

# %%
quantidades = [100]
valor_max = 1000000

tempos_pesquisa_binaria_ordenado = {"melhor_caso": [], "pior_caso": [], "caso_intermedio": []}

for quantidade in quantidades:
    ficheiro_ordenado = f'ordenado_{quantidade}.txt'
    with open(ficheiro_ordenado, 'r') as ficheiro:
        linhas = ficheiro.readlines()
        inteiros = [int(numero) for linha in linhas for numero in linha.strip().replace('[', '').replace(']', '').split(',')]

    item_melhor_caso = inteiros[0]

    item_pior_caso = -1

    item_caso_intermedio = inteiros[random.randint(0, len(inteiros) - 1)]

    print(f'Pesquisa Binária para {quantidade} ordenado (Melhor Caso):')
    dic_stats, dic_tempos = a.complexidade(p.pesquisa_binaria, ficheiro_ordenado, [item_melhor_caso], 500)
    tempos_pesquisa_binaria_ordenado["melhor_caso"].extend(dic_tempos[item_melhor_caso])
    print(dic_stats)

    print(f'Pesquisa Binária para {quantidade} ordenado (Pior Caso):')
    dic_stats, dic_tempos = a.complexidade(p.pesquisa_binaria, ficheiro_ordenado, [item_pior_caso], 500)
    tempos_pesquisa_binaria_ordenado["pior_caso"].extend(dic_tempos[item_pior_caso])
    print(dic_stats)

    print(f'Pesquisa Binária para {quantidade} ordenado (Caso Intermediário):')
    dic_stats, dic_tempos = a.complexidade(p.pesquisa_binaria, ficheiro_ordenado, [item_caso_intermedio], 500)
    tempos_pesquisa_binaria_ordenado["caso_intermedio"].extend(dic_tempos[item_caso_intermedio])
    print(dic_stats)
# Out:
# Pesquisa Binária para 100 ordenado (Melhor Caso):
# {8926: (0.0015624074935913087, 0.0005468354998581244)}
# Pesquisa Binária para 100 ordenado (Pior Caso):
# {-1: (0.0014922566413879395, 0.0004919359538336412)}
# Pesquisa Binária para 100 ordenado (Caso Intermediário):
# {759407: (0.0014510202407836915, 0.00045914126832670915)}

# %%
a.complexidade_boxplot(tempos_pesquisa_binaria_ordenado)

# %% [markdown]
# ### Estudo do melhor caso, pior caso e do caso intermédio na função da pesquisa binária recursiva

# %%
quantidades = [100]
valor_max = 1000000

tempos_pesquisa_binaria_recursiva_ordenado = {"melhor_caso": [], "pior_caso": [], "caso_intermedio": []}

for quantidade in quantidades:
    ficheiro_ordenado = f'ordenado_{quantidade}.txt'
    with open(ficheiro_ordenado, 'r') as ficheiro:
        linhas = ficheiro.readlines()
        inteiros = [int(numero) for linha in linhas for numero in linha.strip().replace('[', '').replace(']', '').split(',')]

    item_melhor_caso = inteiros[0]

    item_pior_caso = -1

    item_caso_intermedio = inteiros[random.randint(0, len(inteiros) - 1)]

    print(f'Pesquisa Binária Recursiva para {quantidade} ordenado (Melhor Caso):')
    dic_stats, dic_tempos = a.complexidade(p.pesquisa_binaria_recursiva, ficheiro_ordenado, [item_melhor_caso], 500)
    tempos_pesquisa_binaria_recursiva_ordenado["melhor_caso"].extend(dic_tempos[item_melhor_caso])
    print(dic_stats)

    print(f'Pesquisa Binária Recursiva para {quantidade} ordenado (Pior Caso):')
    dic_stats, dic_tempos = a.complexidade(p.pesquisa_binaria_recursiva, ficheiro_ordenado, [item_pior_caso], 500)
    tempos_pesquisa_binaria_recursiva_ordenado["pior_caso"].extend(dic_tempos[item_pior_caso])
    print(dic_stats)

    print(f'Pesquisa Binária Recursiva para {quantidade} ordenado (Caso Intermediário):')
    dic_stats, dic_tempos = a.complexidade(p.pesquisa_binaria_recursiva, ficheiro_ordenado, [item_caso_intermedio], 500)
    tempos_pesquisa_binaria_recursiva_ordenado["caso_intermedio"].extend(dic_tempos[item_caso_intermedio])
    print(dic_stats)
# Out:
# Pesquisa Binária Recursiva para 100 ordenado (Melhor Caso):
# {8926: (0.007982676982879638, 0.001397514284329191)}
# Pesquisa Binária Recursiva para 100 ordenado (Pior Caso):
# {-1: (0.009345640659332275, 0.0009865766270540696)}
# Pesquisa Binária Recursiva para 100 ordenado (Caso Intermediário):
# {126848: (0.00304264497756958, 0.0006466955996229613)}

# %%
a.complexidade_boxplot(tempos_pesquisa_binaria_recursiva_ordenado)

# %% [markdown]
# ## Listas Desordenadas

# %% [markdown]
# ### Estudo do melhor caso, pior caso e do caso intermédio na função da pesquisa sequencial

# %%
quantidades = [100]
valor_max = 1000000

tempos_pesquisa_sequencial_desordenado = {"melhor_caso": [], "pior_caso": [], "caso_intermedio": []}

for quantidade in quantidades:
    ficheiro_desordenado = f'desordenado_{quantidade}.txt'
    with open(ficheiro_desordenado, 'r') as ficheiro:
        linhas = ficheiro.readlines()
        inteiros = [int(numero) for linha in linhas for numero in linha.strip().replace('[', '').replace(']', '').split(',')]

    item_melhor_caso = inteiros[0]

    item_pior_caso = -1

    item_caso_intermedio = inteiros[random.randint(0, len(inteiros) - 1)]

    print(f'Pesquisa Sequencial para {quantidade} desordenado (Melhor Caso):')
    dic_stats, dic_tempos = a.complexidade(p.pesquisa_sequencial, ficheiro_desordenado, [item_melhor_caso], 500)
    tempos_pesquisa_sequencial_desordenado["melhor_caso"].extend(dic_tempos[item_melhor_caso])
    print(dic_stats)

    print(f'Pesquisa Sequencial para {quantidade} desordenado (Pior Caso):')
    dic_stats, dic_tempos = a.complexidade(p.pesquisa_sequencial, ficheiro_desordenado, [item_pior_caso], 500)
    tempos_pesquisa_sequencial_desordenado["pior_caso"].extend(dic_tempos[item_pior_caso])
    print(dic_stats)

    print(f'Pesquisa Sequencial para {quantidade} desordenado (Caso Intermediário):')
    dic_stats, dic_tempos = a.complexidade(p.pesquisa_sequencial, ficheiro_desordenado, [item_caso_intermedio], 500)
    tempos_pesquisa_sequencial_desordenado["caso_intermedio"].extend(dic_tempos[item_caso_intermedio])
    print(dic_stats)
# Out:
# Pesquisa Sequencial para 100 desordenado (Melhor Caso):
# {39107: (0.0, 0.0)}
# Pesquisa Sequencial para 100 desordenado (Pior Caso):
# {-1: (1.9927024841308595e-06, 4.4558182134492976e-05)}
# Pesquisa Sequencial para 100 desordenado (Caso Intermediário):
# {583473: (0.0, 0.0)}

# %%
a.complexidade_boxplot(tempos_pesquisa_sequencial_desordenado)

# %% [markdown]
# ### Estudo do melhor caso, pior caso e do caso intermédio na função da pesquisa sequencial recursiva

# %%
quantidades = [100]
valor_max = 1000000

tempos_pesquisa_sequencial_recursiva_desordenado = {"melhor_caso": [], "pior_caso": [], "caso_intermedio": []}

for quantidade in quantidades:
    ficheiro_desordenado = f'desordenado_{quantidade}.txt'
    with open(ficheiro_desordenado, 'r') as ficheiro:
        linhas = ficheiro.readlines()
        inteiros = [int(numero) for linha in linhas for numero in linha.strip().replace('[', '').replace(']', '').split(',')]

    item_melhor_caso = inteiros[0]

    item_pior_caso = -1

    item_caso_intermedio = inteiros[random.randint(0, len(inteiros) - 1)]

    print(f'Pesquisa Sequencial Recursiva para {quantidade} desordenado (Melhor Caso):')
    dic_stats, dic_tempos = a.complexidade(p.pesquisa_sequencial_recursiva, ficheiro_desordenado, [item_melhor_caso], 500)
    tempos_pesquisa_sequencial_recursiva_desordenado["melhor_caso"].extend(dic_tempos[item_melhor_caso])
    print(dic_stats)

    print(f'Pesquisa Sequencial Recursiva para {quantidade} desordenado (Pior Caso):')
    dic_stats, dic_tempos = a.complexidade(p.pesquisa_sequencial_recursiva, ficheiro_desordenado, [item_pior_caso], 500)
    tempos_pesquisa_sequencial_recursiva_desordenado["pior_caso"].extend(dic_tempos[item_pior_caso])
    print(dic_stats)

    print(f'Pesquisa Sequencial Recursiva para {quantidade} desordenado (Caso Intermediário):')
    dic_stats, dic_tempos = a.complexidade(p.pesquisa_sequencial_recursiva, ficheiro_desordenado, [item_caso_intermedio], 500)
    tempos_pesquisa_sequencial_recursiva_desordenado["caso_intermedio"].extend(dic_tempos[item_caso_intermedio])
    print(dic_stats)
# Out:
# Pesquisa Sequencial Recursiva para 100 desordenado (Melhor Caso):
# {39107: (4.120349884033203e-06, 6.509977681552603e-05)}
# Pesquisa Sequencial Recursiva para 100 desordenado (Pior Caso):
# {-1: (2.0012855529785157e-06, 4.475010538848218e-05)}
# Pesquisa Sequencial Recursiva para 100 desordenado (Caso Intermediário):
# {606256: (2.18963623046875e-06, 4.896175457324521e-05)}

# %%
a.complexidade_boxplot(tempos_pesquisa_sequencial_recursiva_desordenado)

# %% [markdown]
# ### Estudo do melhor caso, pior caso e do caso intermédio na função da pesquisa binária

# %%
quantidades = [100]
valor_max = 1000000

tempos_pesquisa_binaria_desordenado = {"melhor_caso": [], "pior_caso": [], "caso_intermedio": []}

for quantidade in quantidades:
    ficheiro_desordenado = f'desordenado_{quantidade}.txt'
    with open(ficheiro_desordenado, 'r') as ficheiro:
        linhas = ficheiro.readlines()
        inteiros = [int(numero) for linha in linhas for numero in linha.strip().replace('[', '').replace(']', '').split(',')]

    item_melhor_caso = inteiros[0]

    item_pior_caso = -1

    item_caso_intermedio = inteiros[random.randint(0, len(inteiros) - 1)]

    print(f'Pesquisa Binária para {quantidade} desordenado (Melhor Caso):')
    dic_stats, dic_tempos = a.complexidade(p.pesquisa_binaria, ficheiro_desordenado, [item_melhor_caso], 500)
    tempos_pesquisa_binaria_desordenado["melhor_caso"].extend(dic_tempos[item_melhor_caso])
    print(dic_stats)

    print(f'Pesquisa Binária para {quantidade} desordenado (Pior Caso):')
    dic_stats, dic_tempos = a.complexidade(p.pesquisa_binaria, ficheiro_desordenado, [item_pior_caso], 500)
    tempos_pesquisa_binaria_desordenado["pior_caso"].extend(dic_tempos[item_pior_caso])
    print(dic_stats)

    print(f'Pesquisa Binária para {quantidade} desordenado (Caso Intermediário):')
    dic_stats, dic_tempos = a.complexidade(p.pesquisa_binaria, ficheiro_desordenado, [item_caso_intermedio], 500)
    tempos_pesquisa_binaria_desordenado["caso_intermedio"].extend(dic_tempos[item_caso_intermedio])
    print(dic_stats)
# Out:
# Pesquisa Binária para 100 desordenado (Melhor Caso):
# {39107: (0.00012584495544433594, 0.0003390336547866499)}
# Pesquisa Binária para 100 desordenado (Pior Caso):
# {-1: (0.00011433219909667968, 0.0003233002080217098)}
# Pesquisa Binária para 100 desordenado (Caso Intermediário):
# {57293: (0.00011316585540771484, 0.0003175011157397281)}

# %%
a.complexidade_boxplot(tempos_pesquisa_binaria_desordenado)

# %% [markdown]
# ### Estudo do melhor caso, pior caso e do caso intermédio na função da pesquisa binária recursiva

# %%
quantidades = [100]
valor_max = 1000000

tempos_pesquisa_binaria_recursiva_desordenado = {"melhor_caso": [], "pior_caso": [], "caso_intermedio": []}

for quantidade in quantidades:
    ficheiro_desordenado = f'desordenado_{quantidade}.txt'
    with open(ficheiro_desordenado, 'r') as ficheiro:
        linhas = ficheiro.readlines()
        inteiros = [int(numero) for linha in linhas for numero in linha.strip().replace('[', '').replace(']', '').split(',')]

    item_melhor_caso = inteiros[0]

    item_pior_caso = -1

    item_caso_intermedio = inteiros[random.randint(0, len(inteiros) - 1)]

    print(f'Pesquisa Binária Recursiva para {quantidade} desordenado (Melhor Caso):')
    dic_stats, dic_tempos = a.complexidade(p.pesquisa_binaria_recursiva, ficheiro_desordenado, [item_melhor_caso], 500)
    tempos_pesquisa_binaria_recursiva_desordenado["melhor_caso"].extend(dic_tempos[item_melhor_caso])
    print(dic_stats)

    print(f'Pesquisa Binária Recursiva para {quantidade} desordenado (Pior Caso):')
    dic_stats, dic_tempos = a.complexidade(p.pesquisa_binaria_recursiva, ficheiro_desordenado, [item_pior_caso], 500)
    tempos_pesquisa_binaria_recursiva_desordenado["pior_caso"].extend(dic_tempos[item_pior_caso])
    print(dic_stats)

    print(f'Pesquisa Binária Recursiva para {quantidade} desordenado (Caso Intermediário):')
    dic_stats, dic_tempos = a.complexidade(p.pesquisa_binaria_recursiva, ficheiro_desordenado, [item_caso_intermedio], 500)
    tempos_pesquisa_binaria_recursiva_desordenado["caso_intermedio"].extend(dic_tempos[item_caso_intermedio])
    print(dic_stats)
# Out:
# Pesquisa Binária Recursiva para 100 desordenado (Melhor Caso):
# {39107: (0.0005592484474182129, 0.0005066115863407858)}
# Pesquisa Binária Recursiva para 100 desordenado (Pior Caso):
# {-1: (0.0006528267860412598, 0.0005068863100438137)}
# Pesquisa Binária Recursiva para 100 desordenado (Caso Intermediário):
# {935021: (0.0005425338745117188, 0.0005159318971649091)}

# %%
a.complexidade_boxplot(tempos_pesquisa_binaria_recursiva_desordenado)

# %% [markdown]
# ## Discussão dos resultados obtidos

# %% [markdown]
# 1. Podemos concluir que a pesquisa binária é rápida tanto para as listas ordenadas como para as desordenadas
# 2. As listas ordenadas são mais rápidas a analisar do que as desordenadas
